# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Too many different ML algorithms to make a comprehensive pivot table?

# %% [markdown]
# RandomForest
# GradientBoosting
# ExtraTrees
# MLPRegressor
# XGBRegressor
# RadialSVR
# ElasticNet
# Lasso
# DecisionTree
# SigmoidSVR
# Ridge
# LinearSVR
# Deep Learning
# Other

# %%
df = pd.read_csv('20190114_ML_Microbiome_papers.csv')
df = df.loc[:, 'Paper':'# Samples'].dropna()
df = df.replace({'Classify': 'classification', 
                 'classify': 'classification', 
                 'Classification': 'classification',
                 'prediction': 'classification', 
                 'Classiy': 'classification',
                 'Regression': 'regression',
                 'Extra Trees':'ExtraTrees',
                 'Decision Trees': 'DecisionTree',
                 '141 subjects': 141, 
                 'RF': 'RandomForest',
                 'RF, default': 'RandomForest',
                 'L2-LR, optimized': 'Ridge',
                 'L1-LR, default': 'Lasso',
                 'RF, optimized' : 'RandomForest',
                 'L2-LR, default': 'Ridge',
                 'KRR, RBF' : 'Ridge',
                 'SVM, Polynomial': 'SVM',#'SigmoidSVR',
                 'BLR, Gaussian priors': 'Other',
                 'BLR, Laplace priors': 'Other',
                 'SVM, Linear default':'SVM',#'LinearSVR',
                 'SVM, RBF': 'RadialSVR',
                 'KRR, Polynomial': 'Ridge',
                 'L1-LR, optimized':'Lasso',
                 'SVM, Linear optimized':'SVM',#'LinearSVR',
                                  'KNN': 'KNN', 
                 'KNN, optimized':'KNN',
                 'ENET (The elastic net)': 'ElasticNet',
                 'Recursive SVM': 'SVM',#'LinearSVR',
                 'Random Forests':'RandomForest',
                 'Deep Belief Network': 'Deep Learning', 
                 'Multi-Layer RNN': 'Deep Learning',
                 'Distributed RF':'RandomForest', 
                 'CART: rpart': 'Other',
                 'Ensemble Classifier': 'Other',
                 'Deep Neural Netowrk (DNN)': 'Deep Learning', 
                 'KNN, default K = 3':'KNN',
                 'KNN, default K = 11':'KNN', 
                 'KNN, default K = 12':'KNN', 
                 'Lasso linear regression variant':'Lasso', 
                 'Artificial Neural Network': 'Deep Learning',
                 'lasso':'Lasso', 
                 'ERF (Extended RF)':'RandomForest',
                 'Deep Learning': 'Deep Learning', 
                 'NaiveBayes':'Other', 
                 'Sparse Logistic Regression':'Other',
                 'Gradient Boosted Trees':'GradientBoosting',
                 'svmLinear':'SVM',#'LinearSVR',
                 'KNN, default K = 2':'KNN', 
                 'multivariate logistic regression':'Other', 
                 'KNN, default K = 1':'KNN',
                 'Ridge Regression':'Ridge',
                 'Random Forest Regression':'RandomForest', 
                 'KNN, default K = 5':'KNN', 
                 'KNN, default K = 6':'KNN', 
                 'KNN, default K = 4':'KNN', 
                 'KNN, default K = 7':'KNN', 
                 'KNN, default K = 8':'KNN', 
                 'Lasso Regression':'Lasso', 
                 'DMBC (for Dirichlet-multinomial Bayes classifier)': 'Other',
                 'Bayesian Ridge Regression':'Ridge', 
                 'Rf':'RandomForest', 
                 'gbm':'GradientBoosting', 
                 'Gradient Boosted Tree':'GradientBoosting', 
                 'xgbTree':'XGBRegressor', 
                 'KNN, default K = 10':'KNN', 
                 'shrunken centroids method on log frequencies of OTUs using the PAMR package in R':'Other', 
                 'Simple Logistic':'Other', 
                 'knn':'KNN',
                 'deep learning':'Deep Learning', 
                 'KNN, default K = 9':'KNN',
                 'svmRadical':'RadialSVR',
                 'bayesian lasso':'Lasso', 
                 'sequential minimal optimization':'Other', 
                 #'SVM ':'LinearSVR',
                 'Deep Learning (Feed forward artifical neural network with three hidden layers)': 'Deep Learning',
                   'SVM ':'SVM',
                 'Naïve Bayes':'Other',
                 'PNN':'Deep Learning',
                 'Naïve Bayes':'Other',
                 'integrated KNN and SVM':'LinearSVR',
                 'DNN':'Deep Learning',
                 'unsupervised NMF':'Other', 
                 'SourceTracker':'Other',
                 'K neighbors Regression':'KNN',
                 'Support Vector Regression':'LinearSVR',
                 'Elastic Net Regression':'ElasticNet',
                 'Dirichlet-multinomial mixture (DMM)':'Other',
                 'LR':'Other',
                 'Logistic Regression':'Other',
                 'supervised NMF':'Other',
                 'WEKA J48':'Other',
                 'NSC':'Other',
                 'Standard Multilayer Perceptron':'Deep Learning',
                 'UniFrac':'Other',
                 'LMT':'Other', 
                'K-means':'KNN',
                'Bayes Net' :'Other',
                'Jrip':'Other',
                'CART: treebag':'Bagged Decision Tree',
                'JMI (Joint Mutual Information)':'Other',
                'dagging':'Bagged Decision tree',
                'gradient boosting regression':'XGBRegressor',
                'RBF Network':'Other',
                'Decision Stump':'Other',
                'LASSO':'Lasso',
                'MetaGUN (method based on SVM)':'Other',
                'Decision Tree':'DecisionTree',
                'ML':'Other',
                #'Linear Regression':'',
                'Lefse':'Other',
                'SMO' :'Other',
                'J48':'Other',
                'GB':'GradientBoosting',
                'Bagging':'Bagged Decision Tree',
                'HMM':'Other',
                'glmnet':'ElasticNet',
                'NPFS-JMI (Neyman-Pearson Feature Selection - Joint Mutual Information)':'Other',
                'PCT (Predictive Clustering Trees)':'Other',
                 'KNN':'KNN',
                 'SVC':'SVM',
                 'SVR':'LinearSVR',
                 'XGBoost':'XGBRegressor',
                 'Gaussian Process':'Other',
                })
df['# Samples'] = df['# Samples'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6eb4a0af379b> in <module>()
# ----> 1 df = pd.read_csv('20190114_ML_Microbiome_papers.csv')
#       2 df = df.loc[:, 'Paper':'# Samples'].dropna()
#       3 df = df.replace({'Classify': 'classification',
#       4                  'classify': 'classification',
#       5                  'Classification': 'classification',
#
# NameError: name 'pd' is not defined

# %%
df['ML algorithm(s)'].value_counts()
# Out:
# Other               122
# RandomForest        114
# SVM                  57
# Ridge                40
# Lasso                30
# Deep Learning        23
# ElasticNet           14
# LinearSVR            11
# GradientBoosting     10
# RadialSVR             9
# XGBRegressor          5
# DecisionTree          4
# ExtraTrees            3
# Name: ML algorithm(s), dtype: int64

# %%
pv = pd.pivot_table(data=df, index=['Task', 'ML algorithm(s)'], aggfunc={'# Samples': ['count', np.mean, np.median, np.min, np.max], 
                                                                    'Paper': ['count']})
pv#.to_csv('combined_pv.csv', sep=',')
# Out:
#                                 # Samples                                  \
#                                      amax amin count         mean  median
# Task           ML algorithm(s)
# classification DecisionTree         10101  242     4  3874.000000  2576.5
#                Deep Learning        10000   14    19  1124.736842   308.0
#                ElasticNet             344   53     7   196.571429   209.0
#                GradientBoosting        48   14     2    31.000000    31.0
#                Lasso                 2900   53    25   330.840000   200.0
#                LinearSVR              815   10     5   301.400000    50.0
#                Other                10101    2   109   471.697248   143.0
#                RadialSVR              552   98     8   225.250000   175.5
#                RandomForest         15082   14    95   706.473684   140.0
#                Ridge                  552   98    32   225.250000   175.5
# ...

# %%
pd.read_csv('combined_pv.csv', header=[0,1], index_col=[0,1])
# Out:
#                                 # Samples                                  \
#                                      amax amin count         mean  median
# Task           ML algorithm(s)
# classification DecisionTree         10101  242     4  3874.000000  2576.5
#                Deep Learning        10000   14    19  1124.736842   308.0
#                ElasticNet             344   53     7   196.571429   209.0
#                GradientBoosting        48   14     2    31.000000    31.0
#                KNN                    357  200     3   252.333333   200.0
#                Lasso                 2900   53    25   330.840000   200.0
#                LinearSVR             2832   10    25   324.080000   151.0
#                Other                10101    2   106   477.905660   140.5
#                RandomForest         15082   14    95   706.473684   140.0
#                Ridge                  552   98    32   225.250000   175.5
# ...

# %% [markdown]
# # Classification

# %%
KNN
RandomForest
GradientBoosting
ExtraTrees
MLPRegressor
XGBRegressor
RadialSVR
ElasticNet
Lasso
DecisionTree
SigmoidSVR
Ridge
LinearSVR
Deep Learning
Other

# %%
cn = df[df['Task'] == 'classification']
cn = cn.replace({'LinearSVR':'SVM',
                'RadialSVR':'SVM'})
cn
# Out:
#                                                  Paper  \
# 0    Charlson, E.S., et al., Disordered microbial c...
# 2    Liu, Z., et al., Sparse distance-based learnin...
# 3    Liu, Z., et al., Sparse distance-based learnin...
# 4    Liu, Z., et al., Sparse distance-based learnin...
# 5    Liu, Z., et al., Sparse distance-based learnin...
# 6    Liu, Z., et al., Sparse distance-based learnin...
# 7    Saulnier, D.M., et al., Gastrointestinal micro...
# 8    Saulnier, D.M., et al., Gastrointestinal micro...
# 9    Riehle, K., et al., The Genboree Microbiome To...
# 10   Cui, H. and X. Zhang, Alignment-free supervise...
# 11   Cui, H. and X. Zhang, Alignment-free supervise...
# 12   Cui, H. and X. Zhang, Alignment-free supervise...
# 13   Liu, Y., et al., Gene prediction in metagenomi...
# 14   Mason, M.R., et al., Deep sequencing identifie...
# 15   Skraban, J., et al., Gut microbiota patterns a...
# 16   Skraban, J., et al., Gut microbiota patterns a...
# ...

# %%
cn_pv = pd.pivot_table(data=cn, index=['ML algorithm(s)'], aggfunc={'# Samples': ['count', np.mean, np.median, np.min, np.max], 
                                                                    'Paper': ['count']})
cn_pv.loc['MLPRegressor'] = [np.nan, np.nan, np.nan, np.nan,np.nan, 0]
cn_pv.loc['XGBRegressor'] = [np.nan, np.nan, np.nan, np.nan,np.nan, 0]
cn_pv
# Out:
#                  # Samples                                     Paper
#                       amax   amin  count         mean  median  count
# ML algorithm(s)
# DecisionTree       10101.0  242.0    4.0  3874.000000  2576.5    4.0
# Deep Learning      10000.0   14.0   20.0  1251.650000   332.5   20.0
# ElasticNet           344.0   53.0    7.0   196.571429   209.0    7.0
# ExtraTrees          4856.0   82.0    3.0  2312.666667  2000.0    3.0
# GradientBoosting    4856.0   14.0    5.0  1400.000000    82.0    5.0
# Lasso               2900.0   53.0   25.0   330.840000   200.0   25.0
# Other              10101.0    2.0  112.0   521.008929   143.0  112.0
# RandomForest       15082.0   14.0   98.0   755.642857   140.5   98.0
# Ridge                552.0   98.0   32.0   225.250000   175.5   32.0
# SVM                10000.0   10.0   69.0   539.101449   186.0   69.0
# MLPRegressor           NaN    NaN    NaN          NaN     NaN    0.0
# ...

# %%
cn_pv.to_csv('classification_pv.csv', sep=',')

# %% [markdown]
# Recategorize everything using these: (Regression and Categorical)
# RandomForest
# GradientBoosting
# ExtraTrees
# MLPRegressor
# XGBRegressor
# RadialSVR
# ElasticNet
# Lasso
# DecisionTree
# SigmoidSVR
# Ridge
# LinearSVM
# Deep Learning
# Other
#
#
# For empty ones, N/A and 0 papers

# %%
pd.read_csv('classification_pv.csv',  header=[0,1], index_col=[0])
# Out:
#                                                    # Samples              \
#                                                         amax  amin count
# ML algorithm(s)
# BLR                                                      552    98    16
# Bagging                                                 1601  1601     1
# Bayes Net                                                141   141     1
# DNN                                                    10000    14     8
# Decision Stump                                           124   124     1
# Decision Tree                                          10101   242     4
# Dirichlet-multinomial Bayes classifier                    85    57     2
# Dirichlet-multinomial mixture (DMM)                       85    57     2
# Elastic Net                                              344    53     7
# Ensemble                                                1731  1731     1
# GB                                                        48    14     2
# ...

# %% [markdown]
# # Regression

# %%
rn = df[df['Task'] == 'regression']
rn = rn.replace({'SVM':'LinearSVR'})
rn['ML algorithm(s)'].value_counts()
rn
# Out:
#                                                  Paper  \
# 177  Subramanian, S., et al., Persistent gut microb...
# 178  Subramanian, S., et al., Persistent gut microb...
# 179  Subramanian, S., et al., Persistent gut microb...
# 188  Ditzler, G., R. Polikar, and G. Rosen, Multi-L...
# 189  Ditzler, G., R. Polikar, and G. Rosen, Multi-L...
# 190  Ditzler, G., R. Polikar, and G. Rosen, Multi-L...
# 194  Jumpertz von Schwartzenberg, R. and P.J. Turnb...
# 229  Schubert, A.M., H. Sinani, and P.D. Schloss, A...
# 232  Zeevi, D., et al., Personalized Nutrition by P...
# 237  Chen, J., et al., Altered gut microbiota in fe...
# 244  Johnson, H.R., et al., A Machine Learning Appr...
# 245  Johnson, H.R., et al., A Machine Learning Appr...
# 246  Johnson, H.R., et al., A Machine Learning Appr...
# 247  Johnson, H.R., et al., A Machine Learning Appr...
# 248  Johnson, H.R., et al., A Machine Learning Appr...
# 249  Johnson, H.R., et al., A Machine Learning Appr...
# ...

# %%
rn_pv = pd.pivot_table(data=rn, index=['ML algorithm(s)'], aggfunc={'# Samples': ['count', np.mean, np.median, np.min, np.max], 
                                                                    'Paper': ['count']})
rn_pv.loc['SigmoidSVR'] = [np.nan, np.nan, np.nan, np.nan,np.nan, 0]
rn_pv.loc['MLPRegressor'] = [np.nan, np.nan, np.nan, np.nan,np.nan, 0]
rn_pv.loc['DecisionTree'] = [np.nan, np.nan, np.nan, np.nan,np.nan, 0]
rn_pv
# Out:
#                  # Samples                                 Paper
#                       amax  amin count         mean median count
# ML algorithm(s)
# Deep Learning         22.0  22.0   3.0    22.000000   22.0   3.0
# ElasticNet           916.0  39.0   7.0   187.285714   71.0   7.0
# ExtraTrees           916.0  71.0   3.0   356.333333   82.0   3.0
# GradientBoosting     916.0  39.0   5.0   381.600000   82.0   5.0
# Lasso               1046.0  39.0   5.0   257.400000   69.0   5.0
# LinearSVR            916.0  39.0   7.0   187.285714   71.0   7.0
# Other                916.0  39.0  10.0   167.500000   70.0  10.0
# RadialSVR             39.0  39.0   1.0    39.000000   39.0   1.0
# RandomForest         916.0  18.0  16.0   173.562500   82.5  16.0
# Ridge               1046.0  69.0   8.0   302.375000   82.5   8.0
# XGBRegressor        3663.0  39.0   5.0  1119.800000  800.0   5.0
# SigmoidSVR             NaN   NaN   NaN          NaN    NaN   0.0
# ...

# %%
rn_pv.to_csv('regression_pv.csv', sep=',')

# %%
RandomForest
GradientBoosting
ExtraTrees
MLPRegressor
XGBRegressor
RadialSVR
ElasticNet
Lasso
DecisionTree
SigmoidSVR
Ridge
LinearSVR
Deep Learning
Other
